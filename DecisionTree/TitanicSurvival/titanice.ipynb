# %% [markdown]
# Exercise: Build decision tree model to predict survival based on certain parameters.
#
# In this file using following columns build a model to predict if person would survive or not,
#
# Pclass,
# Sex,
# Age,
# Fare
#
# Calculate score of your model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
new_df = df.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], axis='columns')
new_df.head(20)
# Out:
#     Survived  Pclass     Sex   Age     Fare
# 0          0       3    male  22.0   7.2500
# 1          1       1  female  38.0  71.2833
# 2          1       3  female  26.0   7.9250
# 3          1       1  female  35.0  53.1000
# 4          0       3    male  35.0   8.0500
# 5          0       3    male   NaN   8.4583
# 6          0       1    male  54.0  51.8625
# 7          0       3    male   2.0  21.0750
# 8          1       3  female  27.0  11.1333
# 9          1       2  female  14.0  30.0708
# 10         1       3  female   4.0  16.7000
# 11         1       1  female  58.0  26.5500
# 12         0       3    male  20.0   8.0500
# 13         0       3    male  39.0  31.2750
# 14         0       3  female  14.0   7.8542
# 15         1       2  female  55.0  16.0000
# 16         0       3    male   2.0  29.1250
# 17         1       2    male   NaN  13.0000
# 18         0       3  female  31.0  18.0000
# 19         1       3  female   NaN   7.2250

# %%
new_df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# Fare          0
# dtype: int64

# %%
mean_age = math.floor(df['Age'].mean())
new_df['Age'].fillna(mean_age, inplace=True)
new_df.head(10)
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500
# 5         0       3    male  29.0   8.4583
# 6         0       1    male  54.0  51.8625
# 7         0       3    male   2.0  21.0750
# 8         1       3  female  27.0  11.1333
# 9         1       2  female  14.0  30.0708

# %%
new_df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# Fare        0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier as dtc
from sklearn.ensemble import RandomForestClassifier as rfc
from sklearn.linear_model import LogisticRegression as lr

# %%
le_sex = LabelEncoder()
new_df['Sex_train'] = le_sex.fit_transform(new_df['Sex'])
new_df
# Out:
#      Survived  Pclass     Sex   Age     Fare  Sex_train
# 0           0       3    male  22.0   7.2500          1
# 1           1       1  female  38.0  71.2833          0
# 2           1       3  female  26.0   7.9250          0
# 3           1       1  female  35.0  53.1000          0
# 4           0       3    male  35.0   8.0500          1
# ..        ...     ...     ...   ...      ...        ...
# 886         0       2    male  27.0  13.0000          1
# 887         1       1  female  19.0  30.0000          0
# 888         0       3  female  29.0  23.4500          0
# 889         1       1    male  26.0  30.0000          1
# 890         0       3    male  32.0   7.7500          1
#
# [891 rows x 6 columns]

# %%
final_df = new_df.drop('Sex', axis='columns')
final_df
# Out:
#      Survived  Pclass   Age     Fare  Sex_train
# 0           0       3  22.0   7.2500          1
# 1           1       1  38.0  71.2833          0
# 2           1       3  26.0   7.9250          0
# 3           1       1  35.0  53.1000          0
# 4           0       3  35.0   8.0500          1
# ..        ...     ...   ...      ...        ...
# 886         0       2  27.0  13.0000          1
# 887         1       1  19.0  30.0000          0
# 888         0       3  29.0  23.4500          0
# 889         1       1  26.0  30.0000          1
# 890         0       3  32.0   7.7500          1
#
# [891 rows x 5 columns]

# %%
X = final_df[['Pclass', 'Age', 'Fare', 'Sex_train']]
X.head()
# Out:
#    Pclass   Age     Fare  Sex_train
# 0       3  22.0   7.2500          1
# 1       1  38.0  71.2833          0
# 2       3  26.0   7.9250          0
# 3       1  35.0  53.1000          0
# 4       3  35.0   8.0500          1

# %%
y = final_df.Survived
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
#model = DecisionTreeClassifier()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

#model.fit(X_train, y_train)

# %%
np.unique(y_test)
# Out:
# array([0, 1], dtype=int64)

# %%
#model.score(X_test, y_test) * 100

# %% [markdown]
# Determining the Best Model:

# %%
def best_model(x_train, y_train, x_test, y_test):
    rfc_classifier = rfc()
    logistic_nigga = lr()
    decisive_nigga = dtc()
    
    rfc_classifier.fit(x_train, y_train)
    logistic_nigga.fit(x_train, y_train)
    decisive_nigga.fit(x_train, y_train)
    
    dickshionary = {
        'Decision Tree' : rfc_classifier.score(x_test, y_test),
        'logistic regression' : logistic_nigga.score(x_test, y_test),
        'decision tree' : decisive_nigga.score(x_test, y_test)
    } 
    
    high_lst = []
    model_name = []
    for model, accuracy in dickshionary.items():
        high_lst.append(accuracy)
        model_name.append(model)
    print(f'best model: {model_name[np.argmax(high_lst)], np.max(high_lst)}')

# %%
best_model(X_train, y_train, X_test, y_test)
# Out:
# best model: ('Decision Tree', 0.8324022346368715)
